# %% [markdown]
# <a href="https://colab.research.google.com/github/manasakoduri/A4-Pareto-Chart-Skills/blob/main/Manasa_Koduri_A4_Pareto_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

df=pd.read_csv("/content/drive/MyDrive/Manasa K_Pareto chart table - Assignment4.csv")
print(df)
# Out:
#                                           Skill  \
# 0   Business knowledge and environmental skills
# 1           Opportunities and challenges skills
# 2                        Process-centric skills
# 3                      Product knowledge skills
# 4                     Industry knowledge skills
# 5                  Competitive landscape skills
# 6       Technology strategy/adaptability skills
# 7                   Organization agility skills
# 8           Strategic project capability skills
# 9                                 Vision skills
# 10                            Leadership skills
# 11                         Communication skills
#
#                                           Description  Frequency
# 0   Understanding company's strategy, objectives, ...         30
# 1   Understanding the opportunities to increase th...         16
# 2   Understanding IT services and technologies in ...         15
# 3   Understanding company product and services and...         10
# ...

# %%
df.index = df['Skill']

df = df.sort_values(by='Frequency', ascending = False)

df["cumulativePercentage"] = df["Frequency"].cumsum()/df["Frequency"].sum()*100

df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x: round(x,2))
print (df)
# Out:
#                                                                                    Skill  \
# Skill
# Business knowledge and environmental skills  Business knowledge and environmental skills
# Leadership skills                                                      Leadership skills
# Competitive landscape skills                                Competitive landscape skills
# Technology strategy/adaptability skills          Technology strategy/adaptability skills
# Communication skills                                                Communication skills
# Industry knowledge skills                                      Industry knowledge skills
# Organization agility skills                                  Organization agility skills
# Opportunities and challenges skills                  Opportunities and challenges skills
# Process-centric skills                                            Process-centric skills
# ...

# %%
fig, ax = plt.subplots()
ax.bar(df.index, df["Frequency"], color = "C0")

ax.set_xticklabels(df['Skill'], rotation = 90)

ax2 = ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"], color = "C1", marker = "D", ms = 7)
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors = "C0")
ax2.tick_params(axis="y", colors = "C1")

for index, v in df.iterrows() :
        label = round(v['cumulativePercentage'], 1)
        plt.annotate(label, xy= (v['Skill'], v['cumulativePercentage']))

plt.show()
